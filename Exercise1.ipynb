# %% [markdown]
# <a href="https://colab.research.google.com/github/Skytech-cell/My-time-series-project/blob/main/Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
plt.xlabel('year')
plt.ylabel('income')
plt.scatter(df['year'],df['per capita income (US$)'],marker='*',color='red')

# %%
df=pd.read_csv('/content/canada_per_capita_income (1).csv')
df.tail(10)
df=df.sample(n=10)
df
# Out:
#     year  per capita income (US$)
# 42  2012              42665.25597
# 39  2009              32755.17682
# 15  1985              11018.95585
# 26  1996              16699.82668
# 36  2006              32738.26290
# 35  2005              29198.05569
# 46  2016              34229.19363
# 10  1980               8355.96812
# 7   1977               7100.12617
# 41  2011              42334.71121

# %%
f = df.rename(columns={'per capita income (US$)': 'income'})
f
# Out:
#     year       income
# 42  2012  42665.25597
# 39  2009  32755.17682
# 15  1985  11018.95585
# 26  1996  16699.82668
# 36  2006  32738.26290
# 35  2005  29198.05569
# 46  2016  34229.19363
# 10  1980   8355.96812
# 7   1977   7100.12617
# 41  2011  42334.71121

# %%
plt.xlabel('year')
plt.ylabel('income')
plt.scatter(f['year'], f['income'], marker='*', color='red')

# %%
new_df=f.drop('income',axis='columns')
new_df
# Out:
#     year
# 42  2012
# 39  2009
# 15  1985
# 26  1996
# 36  2006
# 35  2005
# 46  2016
# 10  1980
# 7   1977
# 41  2011

# %%
income=f.income
income
# Out:
# 42    42665.25597
# 39    32755.17682
# 15    11018.95585
# 26    16699.82668
# 36    32738.26290
# 35    29198.05569
# 46    34229.19363
# 10     8355.96812
# 7      7100.12617
# 41    42334.71121
# Name: income, dtype: float64

# %%
reg=linear_model.LinearRegression()
reg.fit(new_df,income)
# Out:
# LinearRegression()

# %%
reg.predict([[32755]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([28180233.40168476])

# %%
reg.coef_
# Out:
# array([915.43648894])

# %%
reg.intercept_
# Out:
# -1804888.7936348044

# %%
32755*915.43648894+1804888.7936348044
# Out:
# 31790010.988864508
